# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshkumar1887/Natural-language-processing-/blob/main/Basic%20NLP%20tasks/Remove_punctuation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string

# %%
import string

text = "Hello! How are you? I am learning NLP, it's interesting."

# Remove punctuation
clean_text = text.translate(str.maketrans('', '', string.punctuation))

print(clean_text)
# Out:
# Hello How are you I am learning NLP its interesting

# %% [markdown]
# **Remove Punctuation from Tokenized Words (Common in NLP)**

# %%
import string
import nltk
from nltk.tokenize import word_tokenize

# Download the 'punkt_tab' resource if not already present
nltk.download('punkt_tab')

text = "Hello! How are you? I love NLP."

words = word_tokenize(text)

clean_words = [word for word in words if word not in string.punctuation]

print(clean_words)
# Out:
# ['Hello', 'How', 'are', 'you', 'I', 'love', 'NLP']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
