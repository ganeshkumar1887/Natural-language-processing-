# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshkumar1887/Natural-language-processing-/blob/main/Basic%20NLP%20tasks/finding_next_word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import defaultdict

# %%
text = """
Natural Language Processing is interesting
Natural Language Processing is useful
Natural Language Processing is interesting
"""

# %%
tokens  = text.lower().split()

# %%
tokens
# Out:
# ['natural',
#  'language',
#  'processing',
#  'is',
#  'interesting',
#  'natural',
#  'language',
#  'processing',
#  'is',
#  'useful',
#  'natural',
#  'language',
#  'processing',
#  'is',
#  'interesting']

# %%
bigrams = [(tokens[i],tokens[i+1])for i in range(len(tokens)-1)]

# %%
bigrams
# Out:
# [('natural', 'language'),
#  ('language', 'processing'),
#  ('processing', 'is'),
#  ('is', 'interesting'),
#  ('interesting', 'natural'),
#  ('natural', 'language'),
#  ('language', 'processing'),
#  ('processing', 'is'),
#  ('is', 'useful'),
#  ('useful', 'natural'),
#  ('natural', 'language'),
#  ('language', 'processing'),
#  ('processing', 'is'),
#  ('is', 'interesting')]
